# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
lamda = pd.read_csv('lambda_avg.csv', names= ['param','diffmeansq', 'diffmeansqass'])
xi = pd.read_csv('xi_avg.csv', names= ['param','diffmeansq', 'diffmeansqass'])
tau = pd.read_csv('tau_avg.csv', names= ['param','diffmeansq', 'diffmeansqass'])

# %%
sns.scatterplot(lamda['diffmeansqass'], lamda['param'])
# Out:
# /home/diljeet/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='diffmeansqass', ylabel='param'>

# %%
# Optimum lambda from graph
lamda['param'][lamda['diffmeansqass'].idxmin()]
# Out:
# 99.63

# %%
sns.scatterplot(xi['diffmeansqass'], xi['param'])
# Out:
# /home/diljeet/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='diffmeansqass', ylabel='param'>

# %%
# Optimum xi from graph
xi['param'][xi['diffmeansqass'].idxmin()]
# Out:
# 0.0053

# %%
sns.scatterplot(tau['diffmeansqass'], tau['param'])
# Out:
# /home/diljeet/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='diffmeansqass', ylabel='param'>

# %%
# Optimum tau from graph
tau['param'][tau['diffmeansqass'].idxmin()]
# Out:
# 0.0006

# %% [markdown]
# The graphs for tau and xi are in the expected shape. We can see clear peaks at values close to 0.
#
# For lambda the graph does not show desired results. A possible explanation could be due to using unif_var between 0 and 1 for the random tau and xi. This clearly is not the case as both are heavily skewed to the lower end. As such we shouldl attempt this once more using unif_var(0,0.02). This is a suitable value as it covers over double both xi and tau, which have given valid results.
