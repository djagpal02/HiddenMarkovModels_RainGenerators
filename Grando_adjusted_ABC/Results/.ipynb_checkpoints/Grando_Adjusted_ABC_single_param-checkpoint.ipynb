# %% [markdown]
# # ABC - Estimating single parameters
#
# We have moved the generation of HMM Paramters to within the iterative process. Through this we expect to find intervals where the parameter estimates lie. If this interval is not to large (smaller than the current intervals), this may be useful for to narrow down where to search.
#
# Calculations here were made using the same variables as used by grando.
#
# lambdaE = {10, 20, 30}
# xiE = {0.05, 0.01, 0.005}
# tauE = {1.1, 0.5, 0.1}
#
# if we are estimating lambda, we set lambdaE[3] = uniform(26,35)
# if we are estimating xiE, we set xiE[3] = uniform(0.001,0.007)
# if we are estimating tauE, we set tauE[3] = uniform(0.07,0.2)
#
# The data includes 1000 iterations. We have increased the number of iterations as.
#
# Computation took approx 652.842 seconds.
#
# The graphs below correspond to the ones found in Grando's paper pages 78-80.
#
# The results do not match grandos. They do not have a consitent pattern. The pattern observed in Grando's Results is occasionally observed here but there is no consistentcy.
#
# Attempt 4 somewhat shows the pattern for all 3 parameters. This is most likely close to the outcome Grando has obsereved.

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
headers =['lambda1', 'lambda2', 'lambda3', 'xi_1', 'xi_2', 'xi_3', 'tau_1', 'tau_2', 'tau_3', 'distSit', 'distSitAss']

# %%
lam = pd.read_csv('lam_avg.csv', names = headers)
xi = pd.read_csv('xi_avg.csv', names = headers)
tau = pd.read_csv('tau_avg.csv', names = headers)

# %%
# runtime = 652.842 seconds
# Test Lambda3 

sns.scatterplot(x = lam['distSit'],y = lam['lambda3'])
# Out:
# <AxesSubplot:xlabel='distSit', ylabel='lambda3'>

# %%
# Test xi_3 

sns.scatterplot(x = xi['distSit'],y = xi['xi_3'])
# Out:
# <AxesSubplot:xlabel='distSit', ylabel='xi_3'>

# %%
# Test tau_3 

sns.scatterplot(x = tau['distSit'],y = tau['tau_3'])
# Out:
# <AxesSubplot:xlabel='distSit', ylabel='tau_3'>
