# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("singleSite.csv")
sim_data = pd.read_csv("simulation.csv")

# %%
sns.histplot(data)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(sim_data)
# Out:
# <AxesSubplot:ylabel='Count'>
